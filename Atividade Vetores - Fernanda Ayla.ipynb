# %% [markdown]
# Aluna: Fernanda Ayla Pereira Santana, matrícula: 2019047014

# %%
print ("Olá, vamos identificar se os valores que você irá escolher formarão um conjunto de vetores linearmente dependente ou independente?")
a1= float(input("Insira o valor 1:  "))
a2= float(input("Insira o valor 2:  "))
a3= float(input("Insira o valor 3:  "))

print ("Você escolheu o primeiro conjunto de vetores, abaixo insira os valores para formar o segundo conjunto")
b1= float(input("Insira o valor 1:  ") )
b2= float(input("Insira o valor 2:  ")  )
b3= float(input("Insira o valor 3:  ")  )

operacaod1= (a1*b2)-(a2*b1)
operacaod2= (a1*b3)-(a3*b1)
operacaod3= (a2*b3)-(a3*b2)

#print(f"\nResultados das operações: d1 = {operacaod1}, d2 = {operacaod2}, d3 = {operacaod3}")// tornei opcional mostrar o valor de cada operação
if operacaod1==operacaod2==operacaod3:
  print ("Conjunto Linearmente Dependente")
else:
  print ("Conjunto Linearmente Independente")
# Out:
# Olá, vamos identificar se os valores que você irá escolher formarão um conjunto de vetores linearmente dependente ou independente?
# Insira o valor 1:  0
# Insira o valor 2:  0
# Insira o valor 3:  3
# Você escolheu o primeiro conjunto de vetores, abaixo insira os valores para formar o segundo conjunto
# Insira o valor 1:  2
# Insira o valor 2:  2
# Insira o valor 3:  3
# Conjunto Linearmente Independente

# %%
print ("Similar ao que foi feito anteriormente, agora você poderá descobrir se uma tripla ordenada de vetores é linearmente dependente ou independente:")
a1= float(input("Insira o valor 1:  "))
a2= float(input("Insira o valor 2:  ") )
a3= float(input("Insira o valor 3:  ") )

print ("Agora que você inseriu os valores do primeiro vetor, insira os valores para o segundo:")
b1= float(input("Insira o valor 1:  ") )
b2= float(input("Insira o valor 2:  ")  )
b3= float(input("Insira o valor 3:  ")  )

print ("Agora que você inseriu os valores do segundo vetor, insira os valores para o terceiro:")
c1= float(input("Insira o valor 1:  ") )
c2= float(input("Insira o valor 2:  ")  )
c3= float(input("Insira o valor 3:  ")  )


matriz= (a1*b2*c3) + (a2*b3*c1) + (a3*b1*c2) - (a3*b2*c1) - (a1*b3*c2) - (a2*b1*c3)

if matriz == 0:

  print (f"Sua matriz resultou em: {matriz}, portanto os vetores formam um conjunto Linearmente Dependente")


else:
  print (f"Sua matriz resultou em: {matriz}, portanto os vetores formam um conjunto é Linearmente Independente")
# Out:
# Similar ao que foi feito anteriormente, agora você poderá descobrir se uma tripla ordenada de vetores é linearmente dependente ou independente:
# Insira o valor 1:  2
# Insira o valor 2:  1
# Insira o valor 3:  0
# Agora que você inseriu os valores do primeiro vetor, insira os valores para o segundo:
# Insira o valor 1:  0.5
# Insira o valor 2:  1
# Insira o valor 3:  -1
# Agora que você inseriu os valores do segundo vetor, insira os valores para o terceiro0:
# Insira o valor 1:  3
# Insira o valor 2:  1
# Insira o valor 3:  5
# Sua matriz resultou em:6.5, portanto seu conjunto é Linearmente Independente
